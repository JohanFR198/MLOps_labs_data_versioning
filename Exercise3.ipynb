# %%
pip install dvc
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.7 MB ? eta -:--:--
#    --------------- ------------------------ 3.7/9.7 MB 16.8 MB/s eta 0:00:01
#    ---------------------------------------  9.7/9.7 MB 23.2 MB/s eta 0:00:01
#    ---------------------------------------- 9.7/9.7 MB 21.6 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#    -------------------- ------------------- 6.3/12.3 MB 29.7 MB/s eta 0:00:01
#    ---------------------------------------  12.1/12.3 MB 28.0 MB/s eta 0:00:01
#    ---------------------------------------- 12.3/12.3 MB 26.6 MB/s  0:00:00
# ...
#
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
# ...

# %%
import pandas as pd
import dvc.api

path='data/wine_original.csv'
repo='C:\\Users\\Johan Fonseca\\OneDrive - Data ScienceTech Institute\\ML Ops\\data_versioning'

data_url = dvc.api.get_url(
  path=path,
  repo=repo
  )

data = pd.read_csv(data_url, sep=";")
print(data)
# Out:
#      fixed acidity volatile acidity citric acid residual sugar chlorides  \
# 0              7.4              0.7           0            1.9     0.076
# 1              7.8             0.88           0            2.6     0.098
# 2              7.8             0.76        0.04            2.3     0.092
# 3             11.2             0.28        0.56            1.9     0.075
# 4              7.4              0.7           0            1.9     0.076
# ...            ...              ...         ...            ...       ...
# 9393           NaN              NaN         NaN            NaN       NaN
# 9394           NaN              NaN         NaN            NaN       NaN
# 9395           NaN              NaN         NaN            NaN       NaN
# 9396           NaN              NaN         NaN            NaN       NaN
# 9397           NaN              NaN         NaN            NaN       NaN
#
#      free sulfur dioxide total sulfur dioxide density    pH sulphates alcohol  \
# ...

# %%
import pandas as pd
import dvc.api

path='data/wine_original.csv'
repo='C:\\Users\\Johan Fonseca\\OneDrive - Data ScienceTech Institute\\ML Ops\\data_versioning'

data_url = dvc.api.get_url(
  path=path,
  repo=repo,
  rev = "v2"
  )

data_v2 = pd.read_csv(data_url, sep=";")
print(data_v2	)
# Out:
#      fixed acidity volatile acidity citric acid residual sugar chlorides  \
# 0              7.4              0.7           0            1.9     0.076
# 1              7.8             0.88           0            2.6     0.098
# 2              7.8             0.76        0.04            2.3     0.092
# 3             11.2             0.28        0.56            1.9     0.075
# 4              7.4              0.7           0            1.9     0.076
# ...            ...              ...         ...            ...       ...
# 9595           NaN              NaN         NaN            NaN       NaN
# 9596           NaN              NaN         NaN            NaN       NaN
# 9597           NaN              NaN         NaN            NaN       NaN
# 9598           NaN              NaN         NaN            NaN       NaN
# 9599           NaN              NaN         NaN            NaN       NaN
#
#      free sulfur dioxide total sulfur dioxide density    pH sulphates alcohol  \
# ...
